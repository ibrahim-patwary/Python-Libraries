# %% [markdown]
# WElcome to matolotlib

# %% [markdown]
# Plotting x and y points

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints=np.array([0,6])
ypoints=np.array([0,150])
plt.xlabel("Day")
plt.ylabel("Temperature")
plt.title("Weather")
#plot() by defult function 
#The plot() function is used to draw points (markers) in a diagram.
plt.plot(xpoints,ypoints,linestyle="dotted",linewidth=2.5)
# show() by defult function
plt.show()

# %% [markdown]
# Plotting Without Line

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints= np.array([1,8])
ypoints=np.array([3,10])

plt.plot(xpoints,ypoints,'o')
plt.show()

# %% [markdown]
# Multiple Points

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints=np.array([2,4,6,8])
ypoints=np.array([3,7.5,4,10])

plt.plot(xpoints,ypoints)
plt.savefig("plots.pdf")
plt.show()

# %% [markdown]
# Multiple Plotting Without Line

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints=np.array([2,4,6,8])
ypoints=np.array([3,7.5,4,10])

plt.plot(xpoints,ypoints,'.')
plt.show()

# %% [markdown]
# Markers

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints=np.array([3,4,4.5,9])

plt.plot(ypoints,marker='o')
plt.show()

# %% [markdown]
# Format Strings fmt

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints=([1,10,6,3])
plt.plot(ypoints,'o:r')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints=([1,5,1.5,8,2])
plt.plot(ypoints,'o:m')
plt.show()

# %% [markdown]
# Marker Size

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints=np.array([1,5,1.5,8,2])
plt.plot(ypoints,marker='o',ms=10)
#ms= marker size
plt.show()

# %% [markdown]
#  Marker face color

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints= np.array([1,5,2,8])
plt.plot(ypoints,marker='o',ms=15,mfc='m')
plt.show()

# %% [markdown]
# Marker edge color

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints= np.array([1,5,2,8])
plt.plot(ypoints,marker='o',ms=15,mfc='m',mec='m')
plt.show()

# %% [markdown]
# Line style

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints=np.array([1,5.5,1.5,9])
plt.plot(ypoints,linestyle="dotted")
plt.show()

# %% [markdown]
# Line Color

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints=np.array([3,7,2,10])
plt.plot(ypoints,color='m')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints=np.array([3,7,2,10])
plt.plot(ypoints,color='k')
plt.show()

# %% [markdown]
# Multiple Lines

# %%
import matplotlib.pyplot as plt
import numpy as np

y1 = np.array([3, 8, 1, 10])
y2 = np.array([6, 2, 7, 11])

plt.plot(y1,color='r',label="Time")
plt.plot(y2,color='g',label="Date")
plt.legend()
plt.show()

# %% [markdown]
# Create Labels for a Plot

# %%
import numpy as np
import matplotlib.pyplot as plt


# Fixing random state for reproducibility
np.random.seed(19680801)

# Compute pie slices
N = 20
theta = np.linspace(0.0, 2 * np.pi, N, endpoint=False)
radii = 10 * np.random.rand(N)
width = np.pi / 4 * np.random.rand(N)
colors = plt.cm.viridis(radii / 10.)

ax = plt.subplot(111, projection='polar')
ax.bar(theta, radii, width=width, bottom=0.0, color=colors, alpha=0.5)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt


data = [[ 66386, 174296,  75131, 577908,  32015],
        [ 58230, 381139,  78045,  99308, 160454],
        [ 89135,  80552, 152558, 497981, 603535],
        [ 78415,  81858, 150656, 193263,  69638],
        [139361, 331509, 343164, 781380,  52269]]

columns = ('Freeze', 'Wind', 'Flood', 'Quake', 'Hail')
rows = ['%d year' % x for x in (100, 50, 20, 10, 5)]

values = np.arange(0, 2500, 500)
value_increment = 1000

# Get some pastel shades for the colors
colors = plt.cm.BuPu(np.linspace(0, 0.5, len(rows)))
n_rows = len(data)

index = np.arange(len(columns)) + 0.3
bar_width = 0.4

# Initialize the vertical-offset for the stacked bar chart.
y_offset = np.zeros(len(columns))

# Plot bars and create text labels for the table
cell_text = []
for row in range(n_rows):
    plt.bar(index, data[row], bar_width, bottom=y_offset, color=colors[row])
    y_offset = y_offset + data[row]
    cell_text.append(['%1.1f' % (x / 1000.0) for x in y_offset])
# Reverse colors and text labels to display the last value at the top.
colors = colors[::-1]
cell_text.reverse()

# Add a table at the bottom of the axes
the_table = plt.table(cellText=cell_text,
                      rowLabels=rows,
                      rowColours=colors,
                      colLabels=columns,
                      loc='bottom')

# Adjust layout to make room for the table:
plt.subplots_adjust(left=0.2, bottom=0.2)

plt.ylabel("Loss in ${0}'s".format(value_increment))
plt.yticks(values * value_increment, ['%d' % val for val in values])
plt.xticks([])
plt.title('Loss by Disaster')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([0,6])
y=np.array([0,145])
plt.plot(x,y,color='k')
plt.xlabel("Date(June)")
plt.ylabel("Temputure")
plt.show()

# %% [markdown]
# Create a Title for a Plot

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([0,6])
y=np.array([0,145])
plt.plot(x,y,color='m')
plt.xlabel("Date(June)")
plt.ylabel("Temputure")
plt.title("Show data")
plt.show()

# %% [markdown]
# Set Font Properties for Title and Labels

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([0,6])
y=np.array([0,145])
font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}
plt.plot(x,y,color='m')
plt.xlabel("Date(June)",fontdict=font1)
plt.ylabel("Temputure",fontdict=font1)
plt.title("Show data",fontdict=font2)
plt.show()

# %% [markdown]
# Add Grid Lines to a Plot

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([0,6])
y=np.array([0,145])
plt.plot(x,y,color='m')
plt.xlabel("Time")
plt.ylabel("Velocity")
plt.title("Acceleration")
plt.grid()
plt.show()

# %% [markdown]
# Display Multiple Plots and title or super title

# %%
import matplotlib.pyplot as plt
import numpy as np

#plot 1
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)
#the figure has 1 row, 2 columns, and this plot is the first plot.
plt.plot(x,y)
#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 15])

plt.subplot(1, 2, 2)
#the figure has 1 row, 2 columns, and this plot is the second plot.
plt.suptitle("All in one")
plt.plot(x,y)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(3, 1, 1)
plt.title("1th day")
plt.plot(x,y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(3, 1, 2)
plt.title("2nd day")
plt.plot(x,y,color='r')

#plot 3:
x=np.array([0,4,8,9])
y=np.array([3,7,2,10])
plt.subplot(3, 1, 3)
plt.title("3rd day")
plt.plot(x,y,color='m')
plt.show()

# %% [markdown]
# Creating Scatter Plots

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])

plt.scatter(x,y,color='hotpink')
plt.show()

# %% [markdown]
# How to Use the ColorMap

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])

plt.scatter(x, y, c=colors, cmap='viridis')
plt.colorbar()
plt.grid()
#for show colorbar
plt.show()

# %% [markdown]
# Creating Bars

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["Ibrahim", "Tapu", "Adnan", "Tanvir"])
y = np.array([3.76, 3.87, 3.44, 3.10])

plt.title("CGPA")
plt.bar(x,y,color='c')
plt.show()

# %% [markdown]
# Create Histogram

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.random.normal(170, 10, 250)

plt.hist(x,color='c')
plt.title("Histogram")
plt.show()

# %% [markdown]
# Creating Pie Charts

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
plt.pie(y,labels=mylabels)
plt.title("Pie charts")
plt.show()

# %% [markdown]
# Legend

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels = mylabels)
plt.legend()
plt.show()

# %% [markdown]
# Legend With Header

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels = mylabels)
plt.legend(title = "Four Fruits:")
plt.show()
