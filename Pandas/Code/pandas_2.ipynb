# %% [markdown]
# Read CSV file

# %% [markdown]
# Shortcuts- If you went to see whole attributes in any kind of function, then will click those function and simply click Alter key in your keybroad..

# %%
import pandas as pd
df=pd.read_csv("https://raw.githubusercontent.com/codebasics/py/master/pandas/1_intro/nyc_weather.csv")
df
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# ...

# %% [markdown]
# What is the maximum temperature

# %%
import pandas as pd
df=pd.read_csv("https://raw.githubusercontent.com/codebasics/py/master/pandas/1_intro/nyc_weather.csv")
print("Maximum Temperature is ",end="")
df["Temperature"].max()
# Out:
# Maximum Temperature is
# 50

# %% [markdown]
# Which days were rainy?

# %%
import pandas as pd
df=pd.read_csv("https://raw.githubusercontent.com/codebasics/py/master/pandas/1_intro/nyc_weather.csv")
print("Rainy days were : ")
df["EST"][df["Events"]=="Rain"]
# Out:
# Rainy days were :
# 8      1/9/2016
# 9     1/10/2016
# 15    1/16/2016
# 26    1/27/2016
# Name: EST, dtype: object

# %% [markdown]
# What is average wind speed ?

# %%
import pandas as pd
df=pd.read_csv("https://raw.githubusercontent.com/codebasics/py/master/pandas/1_intro/nyc_weather.csv")
print("Average Wind speed is : ")
df["WindSpeedMPH"].mean()
# Out:
# Average Wind speed is :
# 6.892857142857143

# %% [markdown]
# Fill up NaN value with Zero(0)

# %%
import pandas as pd
df=pd.read_csv("https://raw.githubusercontent.com/codebasics/py/master/pandas/1_intro/nyc_weather.csv")
df.fillna(0,inplace=True)
df
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# ...

# %% [markdown]
# Data Frame

# %%
import pandas as pd
weather_data={
    
    'day':["1/1/2017",'1/2/2017','1/3/2017','1/4/2017','1/5/2017','1/6/2017'],
    'temperature':[32,35,28,24,32,31],
    'windspeed':[6,7,2,7,4,2],
    'event':['Rain','Sunny','Snow','Snow','Rain','Sunny']

    }

df=pd.DataFrame(weather_data)
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %% [markdown]
# Data set Shape

# %%
import pandas as pd
weather_data={
    
    'day':["1/1/2017",'1/2/2017','1/3/2017','1/4/2017','1/5/2017','1/6/2017'],
    'temperature':[32,35,28,24,32,31],
    'windspeed':[6,7,2,7,4,2],
    'event':['Rain','Sunny','Snow','Snow','Rain','Sunny']

    }

df=pd.DataFrame(weather_data) 
rows,columns=df.shape
print("Number of Rows: ",rows)
print("Number of columns: ",columns)
# Out:
# Number of Rows:  6
# Number of columns:  4

# %% [markdown]
# Head Function for pandas

# %%
import pandas as pd
weather_data={
    
    'day':["1/1/2017",'1/2/2017','1/3/2017','1/4/2017','1/5/2017','1/6/2017'],
    'temperature':[32,35,28,24,32,31],
    'windspeed':[6,7,2,7,4,2],
    'event':['Rain','Sunny','Snow','Snow','Rain','Sunny']

    }

df=pd.DataFrame(weather_data) 
df.head()
#It's initially print 1st 5 rows
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain

# %% [markdown]
# Tail Function

# %%
import pandas as pd
weather_data={
    
    'day':["1/1/2017",'1/2/2017','1/3/2017','1/4/2017','1/5/2017','1/6/2017'],
    'temperature':[32,35,28,24,32,31],
    'windspeed':[6,7,2,7,4,2],
    'event':['Rain','Sunny','Snow','Snow','Rain','Sunny']

    }

df=pd.DataFrame(weather_data) 
df.tail(2)
#It's print last 5 rows
# Out:
#         day  temperature  windspeed  event
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %% [markdown]
# Slicing
#
# print Row number 2 to 4

# %%
import pandas as pd
weather_data={
    
    'day':["1/1/2017",'1/2/2017','1/3/2017','1/4/2017','1/5/2017','1/6/2017'],
    'temperature':[32,35,28,24,32,31],
    'windspeed':[6,7,2,7,4,2],
    'event':['Rain','Sunny','Snow','Snow','Rain','Sunny']

    }

df=pd.DataFrame(weather_data) 
df[2:5]
# Out:
#         day  temperature  windspeed event
# 2  1/3/2017           28          2  Snow
# 3  1/4/2017           24          7  Snow
# 4  1/5/2017           32          4  Rain

# %% [markdown]
# Print dataset colmuns name

# %%
import pandas as pd
weather_data={
    
    'day':["1/1/2017",'1/2/2017','1/3/2017','1/4/2017','1/5/2017','1/6/2017'],
    'temperature':[32,35,28,24,32,31],
    'windspeed':[6,7,2,7,4,2],
    'event':['Rain','Sunny','Snow','Snow','Rain','Sunny']

    }

df=pd.DataFrame(weather_data) 
df.columns
# Out:
# Index(['day', 'temperature', 'windspeed', 'event'], dtype='object')

# %% [markdown]
# Print individual Colmuns value

# %%
import pandas as pd
weather_data={
    
    'day':["1/1/2017",'1/2/2017','1/3/2017','1/4/2017','1/5/2017','1/6/2017'],
    'temperature':[32,35,28,24,32,31],
    'windspeed':[6,7,2,7,4,2],
    'event':['Rain','Sunny','Snow','Snow','Rain','Sunny']

    }

df=pd.DataFrame(weather_data) 
df.day#df["day"]
# Out:
# 0    1/1/2017
# 1    1/2/2017
# 2    1/3/2017
# 3    1/4/2017
# 4    1/5/2017
# 5    1/6/2017
# Name: day, dtype: object

# %%
import pandas as pd
weather_data={
    
    'day':["1/1/2017",'1/2/2017','1/3/2017','1/4/2017','1/5/2017','1/6/2017'],
    'temperature':[32,35,28,24,32,31],
    'windspeed':[6,7,2,7,4,2],
    'event':['Rain','Sunny','Snow','Snow','Rain','Sunny']

    }

df=pd.DataFrame(weather_data) 
df["event"]#df.event
# Out:
# 0     Rain
# 1    Sunny
# 2     Snow
# 3     Snow
# 4     Rain
# 5    Sunny
# Name: event, dtype: object

# %% [markdown]
# Costums colmuns and print

# %%
import pandas as pd
weather_data={
    
    'day':["1/1/2017",'1/2/2017','1/3/2017','1/4/2017','1/5/2017','1/6/2017'],
    'temperature':[32,35,28,24,32,31],
    'windspeed':[6,7,2,7,4,2],
    'event':['Rain','Sunny','Snow','Snow','Rain','Sunny']

    }

df=pd.DataFrame(weather_data) 
df[["event","day","temperature"]]
# Out:
#    event       day  temperature
# 0   Rain  1/1/2017           32
# 1  Sunny  1/2/2017           35
# 2   Snow  1/3/2017           28
# 3   Snow  1/4/2017           24
# 4   Rain  1/5/2017           32
# 5  Sunny  1/6/2017           31

# %% [markdown]
# Maximun temperatue

# %%
import pandas as pd
weather_data={
    
    'day':["1/1/2017",'1/2/2017','1/3/2017','1/4/2017','1/5/2017','1/6/2017'],
    'temperature':[32,35,28,24,32,31],
    'windspeed':[6,7,2,7,4,2],
    'event':['Rain','Sunny','Snow','Snow','Rain','Sunny']

    }


print("Maximun Temperature: ",df["temperature"].max())
# Out:
# Maximun Temperature:  35

# %% [markdown]
# Average temperature

# %%
import pandas as pd
weather_data={
    
    'day':["1/1/2017",'1/2/2017','1/3/2017','1/4/2017','1/5/2017','1/6/2017'],
    'temperature':[32,35,28,24,32,31],
    'windspeed':[6,7,2,7,4,2],
    'event':['Rain','Sunny','Snow','Snow','Rain','Sunny']

    }
print("Average temperature: ",end="")
df["temperature"].mean()
# Out:
# Average temperature:
# 30.333333333333332

# %% [markdown]
# describe() function is used to get a descriptive statistics summary of a given dataframe. This includes mean, count, std deviation, percentiles, and min-max values of all the features

# %%
import pandas as pd
weather_data={
    
    'day':["1/1/2017",'1/2/2017','1/3/2017','1/4/2017','1/5/2017','1/6/2017'],
    'temperature':[32,35,28,24,32,31],
    'windspeed':[6,7,2,7,4,2],
    'event':['Rain','Sunny','Snow','Snow','Rain','Sunny']

    }

df.describe()
# Out:
#        temperature  windspeed
# count     6.000000   6.000000
# mean     30.333333   4.666667
# std       3.829708   2.338090
# min      24.000000   2.000000
# 25%      28.750000   2.500000
# 50%      31.500000   5.000000
# 75%      32.000000   6.750000
# max      35.000000   7.000000

# %% [markdown]
# Find Out the date when temperature is maximum

# %%
import pandas as pd
weather_data={
    
    'day':["1/1/2017",'1/2/2017','1/3/2017','1/4/2017','1/5/2017','1/6/2017'],
    'temperature':[32,35,28,24,32,31],
    'windspeed':[6,7,2,7,4,2],
    'event':['Rain','Sunny','Snow','Snow','Rain','Sunny']

    }
df=pd.DataFrame(weather_data) 
df[['day','temperature']][df.temperature==df["temperature"].max()]
# Out:
#         day  temperature
# 1  1/2/2017           35

# %% [markdown]
# Set Index

# %%
import pandas as pd
weather_data={
    
    'day':["1/1/2017",'1/2/2017','1/3/2017','1/4/2017','1/5/2017','1/6/2017'],
    'temperature':[32,35,28,24,32,31],
    'windspeed':[6,7,2,7,4,2],
    'event':['Rain','Sunny','Snow','Snow','Rain','Sunny']

    }
df=pd.DataFrame(weather_data) 
df.set_index("day",inplace=True)
df
# Out:
#           temperature  windspeed  event
# day
# 1/1/2017           32          6   Rain
# 1/2/2017           35          7  Sunny
# 1/3/2017           28          2   Snow
# 1/4/2017           24          7   Snow
# 1/5/2017           32          4   Rain
# 1/6/2017           31          2  Sunny

# %% [markdown]
# loc() function

# %%
import pandas as pd
weather_data={
    
    'day':["1/1/2017",'1/2/2017','1/3/2017','1/4/2017','1/5/2017','1/6/2017'],
    'temperature':[32,35,28,24,32,31],
    'windspeed':[6,7,2,7,4,2],
    'event':['Rain','Sunny','Snow','Snow','Rain','Sunny']

    }
df=pd.DataFrame(weather_data) 
df.set_index("day",inplace=True)
df.loc["1/4/2017"]
# Out:
# temperature      24
# windspeed         7
# event          Snow
# Name: 1/4/2017, dtype: object

# %% [markdown]
# Un set index

# %%
import pandas as pd
weather_data={
    
    'day':["1/1/2017",'1/2/2017','1/3/2017','1/4/2017','1/5/2017','1/6/2017'],
    'temperature':[32,35,28,24,32,31],
    'windspeed':[6,7,2,7,4,2],
    'event':['Rain','Sunny','Snow','Snow','Rain','Sunny']

    }
df=pd.DataFrame(weather_data) 
df.reset_index(inplace=True)
df
# Out:
#    index       day  temperature  windspeed  event
# 0      0  1/1/2017           32          6   Rain
# 1      1  1/2/2017           35          7  Sunny
# 2      2  1/3/2017           28          2   Snow
# 3      3  1/4/2017           24          7   Snow
# 4      4  1/5/2017           32          4   Rain
# 5      5  1/6/2017           31          2  Sunny

# %% [markdown]
# List of Tuples to dataset

# %%
import pandas as pd

weather_data=[
             ("1/1/2017",32,6,"Rain"),
             ("1/3/2017",30,6,"Snow"),
             ("1/2/2017",35,7,"Sunny"),
             ("1/3/2017",28,2,"Snow")

]

df=pd.DataFrame(weather_data,columns=["Day","Temperature","Windspeed","Event"])
df
# Out:
#         Day  Temperature  Windspeed  Event
# 0  1/1/2017           32          6   Rain
# 1  1/3/2017           30          6   Snow
# 2  1/2/2017           35          7  Sunny
# 3  1/3/2017           28          2   Snow

# %% [markdown]
# Skiprows Function

# %%
import pandas as pd
df=pd.read_csv("https://raw.githubusercontent.com/codebasics/py/master/pandas/4_read_write_to_excel/stock_data.csv",skiprows=1)
df
# Out:
#   GOOGL          27.82   87   845     larry page
# 0   WMT           4.61  484    65           n.a.
# 1  MSFT             -1   85    64     bill gates
# 2  RIL   not available   50  1023  mukesh ambani
# 3  TATA            5.6   -1  n.a.     ratan tata

# %% [markdown]
# Header function

# %%
import pandas as pd
df=pd.read_csv("https://raw.githubusercontent.com/codebasics/py/master/pandas/4_read_write_to_excel/stock_data.csv",header=None)
df
# Out:
#          0              1        2      3              4
# 0  tickers            eps  revenue  price         people
# 1    GOOGL          27.82       87    845     larry page
# 2      WMT           4.61      484     65           n.a.
# 3     MSFT             -1       85     64     bill gates
# 4     RIL   not available       50   1023  mukesh ambani
# 5     TATA            5.6       -1   n.a.     ratan tata

# %%
import pandas as pd
df=pd.read_csv("https://raw.githubusercontent.com/codebasics/py/master/pandas/4_read_write_to_excel/stock_data.csv",header=None,names=["Ticker","Eps","Revenue","Price","People"])
df
# Out:
#     Ticker            Eps  Revenue  Price         People
# 0  tickers            eps  revenue  price         people
# 1    GOOGL          27.82       87    845     larry page
# 2      WMT           4.61      484     65           n.a.
# 3     MSFT             -1       85     64     bill gates
# 4     RIL   not available       50   1023  mukesh ambani
# 5     TATA            5.6       -1   n.a.     ratan tata

# %% [markdown]
# Replacing values and cleaning

# %%
import pandas as pd
df=pd.read_csv("https://raw.githubusercontent.com/codebasics/py/master/pandas/4_read_write_to_excel/stock_data.csv",na_values=["not available","n.a."])
df
# Out:
#   tickers    eps  revenue   price         people
# 0   GOOGL  27.82       87   845.0     larry page
# 1     WMT   4.61      484    65.0            NaN
# 2    MSFT  -1.00       85    64.0     bill gates
# 3    RIL     NaN       50  1023.0  mukesh ambani
# 4    TATA   5.60       -1     NaN     ratan tata

# %%
import pandas as pd
df=pd.read_csv("https://raw.githubusercontent.com/codebasics/py/master/pandas/4_read_write_to_excel/stock_data.csv",na_values={
  'eps':["not available","n.a."] ,
  'revenue': ["not available","n.a.",-1] ,
  'people': ["not available","n.a."] 

})
df
# Out:
#   tickers    eps  revenue price         people
# 0   GOOGL  27.82     87.0   845     larry page
# 1     WMT   4.61    484.0    65            NaN
# 2    MSFT  -1.00     85.0    64     bill gates
# 3    RIL     NaN     50.0  1023  mukesh ambani
# 4    TATA   5.60      NaN  n.a.     ratan tata

# %% [markdown]
# How to change data type of a colmun
#
# prase_dates()

# %%
import pandas as pd
df=pd.read_csv("/content/weather_data.csv",parse_dates=["day"])
df.set_index("day",inplace=True)
df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          NaN        7.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08         31.0        2.0   Sunny
# 2017-01-09          NaN        NaN     NaN
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %% [markdown]
# Fillna() function .which is replace any values

# %%
import pandas as pd
df=pd.read_csv("/content/weather_data.csv",parse_dates=["day"])
df.set_index("day",inplace=True)
new_df=df.fillna(0)
new_df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          0.0        7.0   Sunny
# 2017-01-05         28.0        0.0    Snow
# 2017-01-06          0.0        7.0       0
# 2017-01-07         32.0        0.0    Rain
# 2017-01-08         31.0        2.0   Sunny
# 2017-01-09          0.0        0.0       0
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
import pandas as pd
df=pd.read_csv("/content/weather_data.csv",parse_dates=["day"])
df.set_index("day",inplace=True)
new_df=df.fillna({
    'temperature':0,
    'windspeed':0,
    'event':"no event"

})
new_df
# Out:
#             temperature  windspeed     event
# day
# 2017-01-01         32.0        6.0      Rain
# 2017-01-04          0.0        7.0     Sunny
# 2017-01-05         28.0        0.0      Snow
# 2017-01-06          0.0        7.0  no event
# 2017-01-07         32.0        0.0      Rain
# 2017-01-08         31.0        2.0     Sunny
# 2017-01-09          0.0        0.0  no event
# 2017-01-10         34.0        8.0    Cloudy
# 2017-01-11         40.0       12.0     Sunny

# %% [markdown]
# Forward fillna function.It's work looks like carry forward
#
# fillna(method="ffill")

# %%
import pandas as pd
df=pd.read_csv("/content/weather_data.csv",parse_dates=["day"])
df.set_index("day",inplace=True)
new_df=df.fillna(method="ffill")
new_df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04         32.0        7.0   Sunny
# 2017-01-05         28.0        7.0    Snow
# 2017-01-06         28.0        7.0    Snow
# 2017-01-07         32.0        7.0    Rain
# 2017-01-08         31.0        2.0   Sunny
# 2017-01-09         31.0        2.0   Sunny
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %% [markdown]
# Interpolate function

# %%
import pandas as pd
df=pd.read_csv("/content/weather_data.csv",parse_dates=["day"])
df.set_index("day",inplace=True)
new_df=df.interpolate()
new_df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04         30.0        7.0   Sunny
# 2017-01-05         28.0        7.0    Snow
# 2017-01-06         30.0        7.0     NaN
# 2017-01-07         32.0        4.5    Rain
# 2017-01-08         31.0        2.0   Sunny
# 2017-01-09         32.5        5.0     NaN
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %% [markdown]
# Interpolate function works for time

# %%
import pandas as pd
df=pd.read_csv("/content/weather_data.csv",parse_dates=["day"])
df.set_index("day",inplace=True)
new_df=df.interpolate(method="time")
new_df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04         29.0        7.0   Sunny
# 2017-01-05         28.0        7.0    Snow
# 2017-01-06         30.0        7.0     NaN
# 2017-01-07         32.0        4.5    Rain
# 2017-01-08         31.0        2.0   Sunny
# 2017-01-09         32.5        5.0     NaN
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %% [markdown]
# Drop function
#
# dropna()

# %%
import pandas as pd
df=pd.read_csv("/content/weather_data.csv",parse_dates=["day"])
df.set_index("day",inplace=True)
new_df=df.dropna(how="all")
#where all value is NaN for each row then it drop this row simply
new_df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          NaN        7.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08         31.0        2.0   Sunny
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %% [markdown]
# Add missing date in our data set

# %%
import pandas as pd
df=pd.read_csv("/content/weather_data.csv",parse_dates=["day"])
df.set_index("day",inplace=True)
dt=pd.date_range("01-01-2017","01-11-2017")
idx=pd.DatetimeIndex(dt)
df=df.reindex(idx)
df
# Out:
#             temperature  windspeed   event
# 2017-01-01         32.0        6.0    Rain
# 2017-01-02          NaN        NaN     NaN
# 2017-01-03          NaN        NaN     NaN
# 2017-01-04          NaN        7.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08         31.0        2.0   Sunny
# 2017-01-09          NaN        NaN     NaN
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
new_df=df.interpolate(method="time")
final=new_df.fillna(method="ffill")
final
# Out:
#             temperature  windspeed   event
# 2017-01-01         32.0   6.000000    Rain
# 2017-01-02         31.0   6.333333    Rain
# 2017-01-03         30.0   6.666667    Rain
# 2017-01-04         29.0   7.000000   Sunny
# 2017-01-05         28.0   7.000000    Snow
# 2017-01-06         30.0   7.000000    Snow
# 2017-01-07         32.0   4.500000    Rain
# 2017-01-08         31.0   2.000000   Sunny
# 2017-01-09         32.5   5.000000   Sunny
# 2017-01-10         34.0   8.000000  Cloudy
# 2017-01-11         40.0  12.000000   Sunny

# %% [markdown]
# Replace() function

# %%
import pandas as pd

df=pd.read_csv("https://raw.githubusercontent.com/codebasics/py/master/pandas/6_handling_missing_data_replace/weather_data.csv")
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017       -99999          7  Sunny
# 2  1/3/2017           28     -99999   Snow
# 3  1/4/2017       -99999          7      0
# 4  1/5/2017           32     -99999   Rain
# 5  1/6/2017           31          2  Sunny
# 6  1/6/2017           34          5      0

# %%
import pandas as pd
import numpy as np
df=pd.read_csv("https://raw.githubusercontent.com/codebasics/py/master/pandas/6_handling_missing_data_replace/weather_data.csv")
new_df=df.replace({
    'temperature':-99999,
    'windspeed' :-99999,
    'event': '0'
},np.NaN)
new_df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017         32.0        6.0   Rain
# 1  1/2/2017          NaN        7.0  Sunny
# 2  1/3/2017         28.0        NaN   Snow
# 3  1/4/2017          NaN        7.0    NaN
# 4  1/5/2017         32.0        NaN   Rain
# 5  1/6/2017         31.0        2.0  Sunny
# 6  1/6/2017         34.0        5.0    NaN

# %%
import  pandas as pd
df=pd.DataFrame({
    'score':['Exceptional','Average','Good','Poor','Exceptional'],
    'student':['Ibrahim','Adnan','Tapu','Tom','Mahi']
})
df
# Out:
#          score  student
# 0  Exceptional  Ibrahim
# 1      Average    Adnan
# 2         Good     Tapu
# 3         Poor      Tom
# 4  Exceptional     Mahi

# %%
df.replace(['Exceptional','Average','Good','Poor'],[4,3,2,1])
# Out:
#    score  student
# 0      4  Ibrahim
# 1      3    Adnan
# 2      2     Tapu
# 3      1      Tom
# 4      4     Mahi

# %% [markdown]
# Group by data set

# %%
import pandas as pd

df= pd.read_csv("/content/weather_by_cities.csv")
df
# Out:
#          day      city  temperature  windspeed   event
# 0   1/1/2017  new york           32          6    Rain
# 1   1/2/2017  new york           36          7   Sunny
# 2   1/3/2017  new york           28         12    Snow
# 3   1/4/2017  new york           33          7   Sunny
# 4   1/1/2017    mumbai           90          5   Sunny
# 5   1/2/2017    mumbai           85         12     Fog
# 6   1/3/2017    mumbai           87         15     Fog
# 7   1/4/2017    mumbai           92          5    Rain
# 8   1/1/2017     paris           45         20   Sunny
# 9   1/2/2017     paris           50         13  Cloudy
# 10  1/3/2017     paris           54          8  Cloudy
# 11  1/4/2017     paris           42         10  Cloudy

# %%
import pandas as pd

df= pd.read_csv("/content/weather_by_cities.csv")
g=df.groupby('city')
for city,city_df in g:
  print(city)
  print(city_df)
# Out:
# mumbai
#         day    city  temperature  windspeed  event
# 4  1/1/2017  mumbai           90          5  Sunny
# 5  1/2/2017  mumbai           85         12    Fog
# 6  1/3/2017  mumbai           87         15    Fog
# 7  1/4/2017  mumbai           92          5   Rain
# new york
#         day      city  temperature  windspeed  event
# 0  1/1/2017  new york           32          6   Rain
# 1  1/2/2017  new york           36          7  Sunny
# 2  1/3/2017  new york           28         12   Snow
# 3  1/4/2017  new york           33          7  Sunny
# paris
#          day   city  temperature  windspeed   event
# 8   1/1/2017  paris           45         20   Sunny
# 9   1/2/2017  paris           50         13  Cloudy
# 10  1/3/2017  paris           54          8  Cloudy
# 11  1/4/2017  paris           42         10  Cloudy

# %%
g.get_group('paris')
# Out:
#          day   city  temperature  windspeed   event
# 8   1/1/2017  paris           45         20   Sunny
# 9   1/2/2017  paris           50         13  Cloudy
# 10  1/3/2017  paris           54          8  Cloudy
# 11  1/4/2017  paris           42         10  Cloudy

# %%
g.max()
# Out:
#                day  temperature  windspeed  event
# city
# mumbai    1/4/2017           92         15  Sunny
# new york  1/4/2017           36         12  Sunny
# paris     1/4/2017           54         20  Sunny

# %%
g.mean()
# Out:
#           temperature  windspeed
# city
# mumbai          88.50       9.25
# new york        32.25       8.00
# paris           47.75      12.75

# %%
g.describe()
# Out:
#          temperature                                                   \
#                count   mean       std   min    25%   50%    75%   max
# city
# mumbai           4.0  88.50  3.109126  85.0  86.50  88.5  90.50  92.0
# new york         4.0  32.25  3.304038  28.0  31.00  32.5  33.75  36.0
# paris            4.0  47.75  5.315073  42.0  44.25  47.5  51.00  54.0
#
#          windspeed
#              count   mean       std  min   25%   50%    75%   max
# city
# mumbai         4.0   9.25  5.057997  5.0  5.00   8.5  12.75  15.0
# new york       4.0   8.00  2.708013  6.0  6.75   7.0   8.25  12.0
# paris          4.0  12.75  5.251984  8.0  9.50  11.5  14.75  20.0

# %%
# %matplotlib inline
g.plot()
# Out:
# city
# mumbai      AxesSubplot(0.125,0.125;0.775x0.755)
# new york    AxesSubplot(0.125,0.125;0.775x0.755)
# paris       AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %% [markdown]
# Concat DataFrame

# %%
import pandas as pd

india_weather=pd.DataFrame({
    'city':["mumbai","delhi",'banglore'],
    'temperature':[32,45,30],
    'humidity':[80,60,78]

})
india_weather
# Out:
#        city  temperature  humidity
# 0    mumbai           32        80
# 1     delhi           45        60
# 2  banglore           30        78

# %%
usa_weather=pd.DataFrame({
    'city':["new york","chicago",'orlando'],
    'temperature':[2,14,35],
    'humidity':[68,65,75]

})
usa_weather
# Out:
#        city  temperature  humidity
# 0  new york            2        68
# 1   chicago           14        65
# 2   orlando           35        75

# %%
df=pd.concat([india_weather,usa_weather],ignore_index=True)
df
# Out:
#        city  temperature  humidity
# 0    mumbai           32        80
# 1     delhi           45        60
# 2  banglore           30        78
# 3  new york            2        68
# 4   chicago           14        65
# 5   orlando           35        75

# %%
df=pd.concat([india_weather,usa_weather],keys=["India","USA"])
df
# Out:
#              city  temperature  humidity
# India 0    mumbai           32        80
#       1     delhi           45        60
#       2  banglore           30        78
# USA   0  new york            2        68
#       1   chicago           14        65
#       2   orlando           35        75

# %%
df.loc["India"]
# Out:
#        city  temperature  humidity
# 0    mumbai           32        80
# 1     delhi           45        60
# 2  banglore           30        78

# %%
temperature_df=pd.DataFrame({
    'city':["new york","chicago",'orlando'],
    'temperature':[2,14,35]
 

})
temperature_df
# Out:
#        city  temperature
# 0  new york            2
# 1   chicago           14
# 2   orlando           35

# %%
import pandas as pd
windspeed_df=pd.DataFrame({
    'city':["new york","chicago",'orlando'],
    'windspeed':[7,12,9]
})
windspeed_df
# Out:
#        city  windspeed
# 0  new york          7
# 1   chicago         12
# 2   orlando          9

# %%
df=pd.concat([temperature_df,windspeed_df],axis=1)
df
# Out:
#        city  temperature      city  windspeed
# 0  new york            2  new york          7
# 1   chicago           14   chicago         12
# 2   orlando           35   orlando          9

# %% [markdown]
# Series

# %%
temperature_df=pd.DataFrame({
    'city':["new york","chicago",'orlando'],
    'temperature':[2,14,35]
 
})
temperature_df
# Out:
#        city  temperature
# 0  new york            2
# 1   chicago           14
# 2   orlando           35

# %%
s=pd.Series(['Humid','Dry','Rain'],name="Event")
s
# Out:
# 0    Humid
# 1      Dry
# 2     Rain
# Name: Event, dtype: object

# %%
df=pd.concat([temperature_df,s],axis=1)
df
# Out:
#        city  temperature  Event
# 0  new york            2  Humid
# 1   chicago           14    Dry
# 2   orlando           35   Rain

# %% [markdown]
# Marge dataset in pandas

# %%
import pandas as pd
temperature_df=pd.DataFrame({
    'city':["new york","chicago",'orlando'],
    'temperature':[2,14,35]
 

})
temperature_df
# Out:
#        city  temperature
# 0  new york            2
# 1   chicago           14
# 2   orlando           35

# %%
import pandas as pd
windspeed_df=pd.DataFrame({
    'city':["new york","chicago",'san franciso'],
    'windspeed':[7,12,9]
})
windspeed_df
# Out:
#            city  windspeed
# 0      new york          7
# 1       chicago         12
# 2  san franciso          9

# %%
import pandas as pd

df= pd.merge(temperature_df,windspeed_df,on="city")
df
# Out:
#        city  temperature  windspeed
# 0  new york            2          7
# 1   chicago           14         12

# %%
import pandas as pd

df= pd.merge(temperature_df,windspeed_df,how="outer")
df
# Out:
#            city  temperature  windspeed
# 0      new york          2.0        7.0
# 1       chicago         14.0       12.0
# 2       orlando         35.0        NaN
# 3  san franciso          NaN        9.0

# %% [markdown]
# Pivot in pandas

# %%
import pandas as pd

df=pd.read_csv("/content/weather.csv")
df
# Out:
#        date      city  temperature  humidity
# 0  5/1/2017  new york           65        56
# 1  5/2/2017  new york           66        58
# 2  5/3/2017  new york           68        60
# 3  5/1/2017    mumbai           75        80
# 4  5/2/2017    mumbai           78        83
# 5  5/3/2017    mumbai           82        85
# 6  5/1/2017   beijing           80        26
# 7  5/2/2017   beijing           77        30
# 8  5/3/2017   beijing           79        35

# %%
df.pivot(index="date",columns="city")
# Out:
#          temperature                 humidity
# city         beijing mumbai new york  beijing mumbai new york
# date
# 5/1/2017          80     75       65       26     80       56
# 5/2/2017          77     78       66       30     83       58
# 5/3/2017          79     82       68       35     85       60

# %%
df.pivot(index="date",columns="city",values="temperature")
# Out:
# city      beijing  mumbai  new york
# date
# 5/1/2017       80      75        65
# 5/2/2017       77      78        66
# 5/3/2017       79      82        68

# %%
import pandas as pd
df=pd.read_csv("/content/weather2.csv")
df
# Out:
#        date      city  temperature  humidity
# 0  5/1/2017  new york           65        56
# 1  5/1/2017  new york           61        54
# 2  5/2/2017  new york           70        60
# 3  5/2/2017  new york           72        62
# 4  5/1/2017    mumbai           75        80
# 5  5/1/2017    mumbai           78        83
# 6  5/2/2017    mumbai           82        85
# 7  5/2/2017    mumbai           80        26

# %%
df.pivot_table(index="city",columns="date")
# Out:
#          humidity          temperature
# date     5/1/2017 5/2/2017    5/1/2017 5/2/2017
# city
# mumbai       81.5     55.5        76.5     81.0
# new york     55.0     61.0        63.0     71.0

# %%
import pandas as pd
df=pd.read_csv("/content/weather3.csv",parse_dates=["date"])
df
# Out:
#         date      city  temperature  humidity
# 0 2017-05-01  new york           65        56
# 1 2017-05-02  new york           61        54
# 2 2017-05-03  new york           70        60
# 3 2017-12-01  new york           30        50
# 4 2017-12-02  new york           28        52
# 5 2017-12-03  new york           25        51

# %%
df.pivot_table(index=pd.Grouper(freq="M",key="date"),columns="city")
# Out:
#              humidity temperature
# city         new york    new york
# date
# 2017-05-31  56.666667   65.333333
# 2017-12-31  51.000000   27.666667

# %% [markdown]
# melt()
#
# function

# %%
import pandas as pd
df=pd.read_csv("/content/weather.csv")
df
# Out:
#          day  chicago  chennai  berlin
# 0     Monday       32       75      41
# 1    Tuesday       30       77      43
# 2  Wednesday       28       75      45
# 3   Thursday       22       82      38
# 4     Friday       30       83      30
# 5   Saturday       20       81      45
# 6     Sunday       25       77      47

# %%
new_df=pd.melt(df,id_vars=["day"],var_name="city",value_name="temperature")
new_df
# Out:
#           day     city  temperature
# 0      Monday  chicago           32
# 1     Tuesday  chicago           30
# 2   Wednesday  chicago           28
# 3    Thursday  chicago           22
# 4      Friday  chicago           30
# 5    Saturday  chicago           20
# 6      Sunday  chicago           25
# 7      Monday  chennai           75
# 8     Tuesday  chennai           77
# 9   Wednesday  chennai           75
# 10   Thursday  chennai           82
# 11     Friday  chennai           83
# 12   Saturday  chennai           81
# 13     Sunday  chennai           77
# 14     Monday   berlin           41
# 15    Tuesday   berlin           43
# 16  Wednesday   berlin           45
# 17   Thursday   berlin           38
# 18     Friday   berlin           30
# 19   Saturday   berlin           45
# 20     Sunday   berlin           47

# %% [markdown]
# Stack Unstack

# %%
import pandas as pd
df=pd.read_excel("/content/stocks.xlsx",header=[0,1])
df
# Out:
#   Unnamed: 0_level_0    Price                  Price to earnings ratio (P/E)  \
#              Company Facebook Google Microsoft                      Facebook
# 0         2017-06-05      155    955        66                         37.10
# 1         2017-06-06      150    987        69                         36.98
# 2         2017-06-07      153    963        62                         36.78
# 3         2017-06-08      155   1000        61                         36.11
# 4         2017-06-09      156   1012        66                         37.07
#
#
#   Google Microsoft
# 0   32.0     30.31
# 1   31.3     30.56
# 2   31.7     30.46
# 3   31.2     30.11
# 4   30.0     31.00

# %%
df_stacked=df.stack()
df_stacked
# Out:
#               Price  Price to earnings ratio (P/E) Unnamed: 0_level_0
# 0 Company       NaN                            NaN         2017-06-05
#   Facebook    155.0                          37.10                NaT
#   Google      955.0                          32.00                NaT
#   Microsoft    66.0                          30.31                NaT
# 1 Company       NaN                            NaN         2017-06-06
#   Facebook    150.0                          36.98                NaT
#   Google      987.0                          31.30                NaT
#   Microsoft    69.0                          30.56                NaT
# 2 Company       NaN                            NaN         2017-06-07
#   Facebook    153.0                          36.78                NaT
#   Google      963.0                          31.70                NaT
#   Microsoft    62.0                          30.46                NaT
# ...

# %%
df_stacked.unstack()
# Out:
#     Price                            Price to earnings ratio (P/E)           \
#   Company Facebook  Google Microsoft                       Company Facebook
# 0     NaN    155.0   955.0      66.0                           NaN    37.10
# 1     NaN    150.0   987.0      69.0                           NaN    36.98
# 2     NaN    153.0   963.0      62.0                           NaN    36.78
# 3     NaN    155.0  1000.0      61.0                           NaN    36.11
# 4     NaN    156.0  1012.0      66.0                           NaN    37.07
#
#                    Unnamed: 0_level_0
#   Google Microsoft            Company Facebook Google Microsoft
# 0   32.0     30.31         2017-06-05      NaT    NaT       NaT
# 1   31.3     30.56         2017-06-06      NaT    NaT       NaT
# 2   31.7     30.46         2017-06-07      NaT    NaT       NaT
# 3   31.2     30.11         2017-06-08      NaT    NaT       NaT
# 4   30.0     31.00         2017-06-09      NaT    NaT       NaT

# %%
import pandas as pd
df=pd.read_excel("/content/stocks_3_levels.xlsx",header=[0,1])
df
# Out:
#   Unnamed: 0_level_0 Price Ratios                     \
#   Unnamed: 0_level_1        Price Price.1    Price.2
# 0            Company     Facebook  Google  Microsoft
# 1            Q1 2016          155     955         66
# 2            Q2 2016          150     987         69
# 3            Q3 2016          153     963         62
# 4            Q4 2016          155    1000         61
# 5            Q1 2017          156    1012         66
#
#                                                                  \
#   Price to earnings ratio (P/E) Price to earnings ratio (P/E).1
# 0                      Facebook                          Google
# 1                          37.1                              32
# 2                         36.98                            31.3
# 3                         36.78                            31.7
# 4                         36.11                            31.2
# 5                         37.07                              30
#
# ...

# %%
df.stack()
# Out:
#                                   Income Statement Price Ratios  \
# 0 Net Profit                              Facebook          NaN
#   Net Profit.1                              Google          NaN
#   Net Profit.2                           Microsoft          NaN
#   Net Sales                               Facebook          NaN
#   Net Sales.1                               Google          NaN
# ...                                            ...          ...
# 5 Price to earnings ratio (P/E).1              NaN           30
#   Price to earnings ratio (P/E).2              NaN           31
#   Price.1                                      NaN         1012
#   Price.2                                      NaN           66
#   Unnamed: 0_level_1                           NaN          NaN
#
#                                   Unnamed: 0_level_0
# 0 Net Profit                                     NaN
#   Net Profit.1                                   NaN
# ...

# %% [markdown]
# Crosstab

# %%
import pandas as pd
df=pd.read_csv("/content/survey.csv")
df
# Out:
#       Name Nationality     Sex  Age Handedness
# 0    Kathy         USA  Female   23      Right
# 1    Linda         USA  Female   18      Right
# 2    Peter         USA    Male   19      Right
# 3     John         USA    Male   22       Left
# 4   Fatima   Bangadesh  Female   31       Left
# 5    Kadir   Bangadesh    Male   25       Left
# 6   Dhaval       India    Male   35       Left
# 7   Sudhir       India    Male   31       Left
# 8   Parvir       India    Male   37      Right
# 9      Yan       China  Female   52      Right
# 10    Juan       China  Female   58       Left
# 11   Liang       China    Male   43       Left

# %%
pd.crosstab(df.Nationality,df.Handedness,margins=True)
# Out:
# Handedness   Left  Right  All
# Nationality
# Bangadesh       2      0    2
# China           2      1    3
# India           2      1    3
# USA             1      3    4
# All             7      5   12

# %%
pd.crosstab([df.Nationality,df.Sex],[df.Handedness],margins=True)
# Out:
# Handedness          Left  Right  All
# Nationality Sex
# Bangadesh   Female     1      0    1
#             Male       1      0    1
# China       Female     1      1    2
#             Male       1      0    1
# India       Male       2      1    3
# USA         Female     0      2    2
#             Male       1      1    2
# All                    7      5   12

# %%
pd.crosstab(df.Nationality,df.Handedness,normalize="index")
# Out:
# Handedness       Left     Right
# Nationality
# Bangadesh    1.000000  0.000000
# China        0.666667  0.333333
# India        0.666667  0.333333
# USA          0.250000  0.750000

# %%
pd.crosstab([df.Sex],[df.Handedness])
# Out:
# Handedness  Left  Right
# Sex
# Female         2      3
# Male           5      2

# %%
import numpy as np
pd.crosstab([df.Sex],[df.Handedness],values=df.Age,aggfunc=np.average)
# Out:
# Handedness  Left  Right
# Sex
# Female      44.5   31.0
# Male        31.2   28.0
